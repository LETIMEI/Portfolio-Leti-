# %% [markdown]
# # Cohort Analysis

# %%
#IMPORT MODULES
import pandas as pd
import numpy as np
import datetime as dt

# visulisation
import seaborn as sns; sns.set()
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
# load data
data = pd.read_excel('Retail_init_cleaned.xlsx')
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 397924 entries, 0 to 397923
# Data columns (total 9 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    397924 non-null  int64
#  1   StockCode    397924 non-null  object
#  2   Description  397924 non-null  object
#  3   Quantity     397924 non-null  int64
#  4   InvoiceDate  397924 non-null  datetime64[ns]
#  5   UnitPrice    397924 non-null  float64
#  6   CustomerID   397924 non-null  int64
#  7   Country      397924 non-null  object
#  8   Amount       397924 non-null  float64
# dtypes: datetime64[ns](1), float64(2), int64(3), object(3)
# memory usage: 27.3+ MB

# %%
data.head(10)
# Out:
#    InvoiceNo StockCode                          Description  Quantity  \
# 0     536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1     536365     71053                  WHITE METAL LANTERN         6
# 2     536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3     536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4     536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# 5     536365     22752         SET 7 BABUSHKA NESTING BOXES         2
# 6     536365     21730    GLASS STAR FROSTED T-LIGHT HOLDER         6
# 7     536366     22633               HAND WARMER UNION JACK         6
# 8     536366     22632            HAND WARMER RED POLKA DOT         6
# 9     536367     84879        ASSORTED COLOUR BIRD ORNAMENT        32
#
#           InvoiceDate  UnitPrice  CustomerID         Country  Amount
# 0 2010-12-01 08:26:00       2.55       17850  United Kingdom   15.30
# 1 2010-12-01 08:26:00       3.39       17850  United Kingdom   20.34
# 2 2010-12-01 08:26:00       2.75       17850  United Kingdom   22.00
# 3 2010-12-01 08:26:00       3.39       17850  United Kingdom   20.34
# 4 2010-12-01 08:26:00       3.39       17850  United Kingdom   20.34
# 5 2010-12-01 08:26:00       7.65       17850  United Kingdom   15.30
# 6 2010-12-01 08:26:00       4.25       17850  United Kingdom   25.50
# 7 2010-12-01 08:28:00       1.85       17850  United Kingdom   11.10
# 8 2010-12-01 08:28:00       1.85       17850  United Kingdom   11.10
# 9 2010-12-01 08:34:00       1.69       13047  United Kingdom   54.08

# %%
data.describe()
# Out:
#            InvoiceNo       Quantity                    InvoiceDate  \
# count  397924.000000  397924.000000                         397924
# mean   560617.126645      13.021823  2011-07-10 23:43:36.912475648
# min    536365.000000       1.000000            2010-12-01 08:26:00
# 25%    549234.000000       2.000000            2011-04-07 11:12:00
# 50%    561893.000000       6.000000            2011-07-31 14:39:00
# 75%    572090.000000      12.000000            2011-10-20 14:33:00
# max    581587.000000   80995.000000            2011-12-09 12:50:00
# std     13106.167695     180.420210                            NaN
#
#            UnitPrice     CustomerID         Amount
# count  397924.000000  397924.000000  397924.000000
# mean        3.116174   15294.315171      22.394749
# min         0.000000   12346.000000       0.000000
# 25%         1.250000   13969.000000       4.680000
# 50%         1.950000   15159.000000      11.800000
# 75%         3.750000   16795.000000      19.800000
# max      8142.750000   18287.000000  168469.600000
# std        22.096788    1713.169877     309.055588

# %% [markdown]
# ## Further data screening and cleaning

# %%
# Using boxplot to detect if there is any Quantity outlier
data.Quantity.plot.box(vert=False);

# %% [markdown]
# The figure suggests rougly most of the **Quantity** falls into the range (0, 28)

# %%
data[data.Quantity >= 28].count()
# Out:
# InvoiceNo      25656
# StockCode      25656
# Description    25656
# Quantity       25656
# InvoiceDate    25656
# UnitPrice      25656
# CustomerID     25656
# Country        25656
# Amount         25656
# dtype: int64

# %%
# a closer look at the Quantity above 10000
Q10000 = data[data.Quantity > 10000]
Q10000
# Out:
#         InvoiceNo StockCode                     Description  Quantity  \
# 37126      541431     23166  MEDIUM CERAMIC TOP STORAGE JAR     74215
# 370473     578841     84826  ASSTD DESIGN 3D PAPER STICKERS     12540
# 397451     581483     23843     PAPER CRAFT , LITTLE BIRDIE     80995
#
#                InvoiceDate  UnitPrice  CustomerID         Country    Amount
# 37126  2011-01-18 10:01:00       1.04       12346  United Kingdom   77183.6
# 370473 2011-11-25 15:57:00       0.00       13256  United Kingdom       0.0
# 397451 2011-12-09 09:15:00       2.08       16446  United Kingdom  168469.6

# %%
Customer16446 = data[data.CustomerID == 16446]
Customer16446
# Out:
#         InvoiceNo StockCode                  Description  Quantity  \
# 133752     553573     22980       PANTRY SCRUBBING BRUSH         1
# 133753     553573     22982          PANTRY PASTRY BRUSH         1
# 397451     581483     23843  PAPER CRAFT , LITTLE BIRDIE     80995
#
#                InvoiceDate  UnitPrice  CustomerID         Country     Amount
# 133752 2011-05-18 09:52:00       1.65       16446  United Kingdom       1.65
# 133753 2011-05-18 09:52:00       1.25       16446  United Kingdom       1.25
# 397451 2011-12-09 09:15:00       2.08       16446  United Kingdom  168469.60

# %% [markdown]
# Customer 16446 only made 3 orders, with the last one being exceptionally large. The order was actually cancelled if you search in the original dataset

# %%
Customer12346 = data[data.CustomerID == 12346]
Customer12346
# Out:
#        InvoiceNo StockCode                     Description  Quantity  \
# 37126     541431     23166  MEDIUM CERAMIC TOP STORAGE JAR     74215
#
#               InvoiceDate  UnitPrice  CustomerID         Country   Amount
# 37126 2011-01-18 10:01:00       1.04       12346  United Kingdom  77183.6

# %% [markdown]
# Customer 12346 only made 1 purchase,and cancelled later as well.

# %%
# Using boxplot to detect if there is any UnitPrice outlier
data.UnitPrice.plot.box(vert=False);

# %%
# without outliers
data.UnitPrice.plot.box(vert=False, showfliers=False);

# %% [markdown]
# Most unit price fall between (0, 7.5)

# %%
data.groupby('Description')['UnitPrice'].mean().nlargest()
# Out:
# Description
# DOTCOM POSTAGE                        744.147500
# PICNIC BASKET WICKER 60 PIECES        649.500000
# Manual                                171.664862
# RUSTIC  SEVENTEEN DRAWER SIDEBOARD    158.076923
# REGENCY MIRROR WITH SHUTTERS          156.428571
# Name: UnitPrice, dtype: float64

# %% [markdown]
# It seems these prices are genuine, some of which are service related.

# %%
# check the unit prices that are greater than £1,000
data[data.UnitPrice >= 1000].sort_values('UnitPrice', ascending=False)
# Out:
#         InvoiceNo StockCode     Description  Quantity         InvoiceDate  \
# 118352     551697      POST         POSTAGE         1 2011-05-03 13:46:00
# 308846     573080         M          Manual         1 2011-10-27 14:20:00
# 308822     573077         M          Manual         1 2011-10-27 14:13:00
# 295254     571751         M          Manual         1 2011-10-19 11:18:00
# 269591     569382         M          Manual         1 2011-10-03 16:44:00
# 208732     562946         M          Manual         1 2011-08-11 09:38:00
# 97061      548813         M          Manual         1 2011-04-04 13:03:00
# 295255     571751         M          Manual         1 2011-10-19 11:18:00
# 97064      548820         M          Manual         1 2011-04-04 13:04:00
# 244129     566927         M          Manual         1 2011-09-15 15:20:00
# 101491     549468         M          Manual         1 2011-04-08 14:27:00
# 76240      546328         M          Manual         1 2011-03-11 10:19:00
# 76241      546329         M          Manual         1 2011-03-11 10:22:00
# 389990     580727       DOT  DOTCOM POSTAGE         1 2011-12-05 17:17:00
# 375623     579196       DOT  DOTCOM POSTAGE         1 2011-11-28 15:54:00
# 344551     576339       DOT  DOTCOM POSTAGE         1 2011-11-14 15:27:00
# 365335     578270       DOT  DOTCOM POSTAGE         1 2011-11-23 13:39:00
# 97063      548813         M          Manual         1 2011-04-04 13:03:00
# 139991     554301         M          Manual         1 2011-05-23 14:46:00
# 139314     554155         M          Manual         1 2011-05-23 11:26:00
# 97588      548913         M          Manual         1 2011-04-05 09:45:00
#
#         UnitPrice  CustomerID         Country   Amount
# 118352    8142.75       16029  United Kingdom  8142.75
# 308846    4161.06       12536          France  4161.06
# 308822    4161.06       12536          France  4161.06
# 295254    3949.32       12744       Singapore  3949.32
# 269591    3155.95       15502  United Kingdom  3155.95
# 208732    2500.00       15581  United Kingdom  2500.00
# 97061     2382.92       12744       Singapore  2382.92
# 295255    2118.74       12744       Singapore  2118.74
# 97064     2053.07       12744       Singapore  2053.07
# 244129    2033.10       17846  United Kingdom  2033.10
# 101491    1867.86       17940  United Kingdom  1867.86
# 76240     1687.17       14911            EIRE  1687.17
# 76241     1687.17       14911            EIRE  1687.17
# 389990    1599.26       14096  United Kingdom  1599.26
# 375623    1526.76       14096  United Kingdom  1526.76
# 344551    1500.36       14096  United Kingdom  1500.36
# 365335    1270.06       14096  United Kingdom  1270.06
# 97063     1252.95       12744       Singapore  1252.95
# 139991    1241.98       12757        Portugal  1241.98
# 139314    1241.98       12757        Portugal  1241.98
# 97588     1136.30       12669          France  1136.30

# %% [markdown]
# We can see that 'DOTCOM POSTAGE', 'Manual', and 'POSTAGE' are amongst the highest unit prices.

# %%
#let's check how many postage are there in the dataset.
data[data.Description.str.contains('postage', case=False, regex=False)]
# Out:
#         InvoiceNo StockCode Description  Quantity         InvoiceDate  \
# 45         536370      POST     POSTAGE         3 2010-12-01 08:45:00
# 377        536403      POST     POSTAGE         1 2010-12-01 11:27:00
# 1112       536527      POST     POSTAGE         1 2010-12-01 13:04:00
# 3798       536840      POST     POSTAGE         1 2010-12-02 18:27:00
# 3978       536852      POST     POSTAGE         1 2010-12-03 09:51:00
# ...           ...       ...         ...       ...                 ...
# 397494     581493      POST     POSTAGE         1 2011-12-09 10:10:00
# 397512     581494      POST     POSTAGE         2 2011-12-09 10:13:00
# 397745     581570      POST     POSTAGE         1 2011-12-09 11:59:00
# 397782     581574      POST     POSTAGE         2 2011-12-09 12:09:00
# 397783     581578      POST     POSTAGE         3 2011-12-09 12:16:00
#
#         UnitPrice  CustomerID      Country  Amount
# 45           18.0       12583       France    54.0
# 377          15.0       12791  Netherlands    15.0
# 1112         18.0       12662      Germany    18.0
# 3798         18.0       12738      Germany    18.0
# 3978         18.0       12686       France    18.0
# ...           ...         ...          ...     ...
# 397494       15.0       12423      Belgium    15.0
# 397512       18.0       12518      Germany    36.0
# 397745       18.0       12662      Germany    18.0
# 397782       18.0       12526      Germany    36.0
# 397783       18.0       12713      Germany    54.0
#
# [1115 rows x 9 columns]

# %% [markdown]
# **Manual** and **postage** seem to be the services provided by the retailer, which are not direct indicator of sales and might skew the data distribution. However, it is at your discretion to remove them all or only the top outliers we identified above.

# %%
# removing service categories
drop_cats = ['POSTAGE', 'Manual', 'DOTCOM POSTAGE']
data = data[~(data.Description.isin(drop_cats))]
data.shape
# Out:
# (396519, 9)

# %%
# removing significant Quantity outliers
data = data[~(data.Quantity >= 28)]
data.shape
# Out:
# (370890, 9)

# %% [markdown]
# ## Cohort Analysis

# %%
data.groupby('Country')['Amount'].sum().nlargest(20).plot(kind='bar', figsize=(12,6));

# %% [markdown]
# We will use the UK data only as it dominates the sales and customers from different countries may vary significantly.

# %%
df_uk = data[data.Country == 'United Kingdom']
# save it to Excel file for later use
df_uk.to_excel('UK_Data.xlsx') #if we don't set index=Flase, it will create a new index
df_uk.shape
# Out:
# (333828, 9)

# %%
df_date = df_uk.set_index('InvoiceDate')
df_date.head()
# Out:
#                      InvoiceNo StockCode                          Description  \
# InvoiceDate
# 2010-12-01 08:26:00     536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER
# 2010-12-01 08:26:00     536365     71053                  WHITE METAL LANTERN
# 2010-12-01 08:26:00     536365    84406B       CREAM CUPID HEARTS COAT HANGER
# 2010-12-01 08:26:00     536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE
# 2010-12-01 08:26:00     536365    84029E       RED WOOLLY HOTTIE WHITE HEART.
#
#                      Quantity  UnitPrice  CustomerID         Country  Amount
# InvoiceDate
# 2010-12-01 08:26:00         6       2.55       17850  United Kingdom   15.30
# 2010-12-01 08:26:00         6       3.39       17850  United Kingdom   20.34
# 2010-12-01 08:26:00         8       2.75       17850  United Kingdom   22.00
# 2010-12-01 08:26:00         6       3.39       17850  United Kingdom   20.34
# 2010-12-01 08:26:00         6       3.39       17850  United Kingdom   20.34

# %% [markdown]
# We next check aggregate monthly sales using resample(), which is a convenience method for frequency conversion and resampling of time series. Here we resample by month end by setting frequency to ‘M’ and aggregate total monthly orders.

# %%
# resample monthly order sum
df_date.Quantity.resample('M').sum()
# Out:
# InvoiceDate
# 2010-12-31    136531
# 2011-01-31    114839
# 2011-02-28    115701
# 2011-03-31    150471
# 2011-04-30    137127
# 2011-05-31    166845
# 2011-06-30    151168
# 2011-07-31    158254
# 2011-08-31    161129
# 2011-09-30    251192
# 2011-10-31    262976
# 2011-11-30    335931
# 2011-12-31     96064
# Freq: M, Name: Quantity, dtype: int64

# %%
# Plotting monthly total orders
df_date.Quantity.resample('M').sum().plot(figsize=(8,4));

# %%
# Let's check total unique customers per month.
df_date.CustomerID.resample('M').nunique()
# Out:
# InvoiceDate
# 2010-12-31     777
# 2011-01-31     617
# 2011-02-28     638
# 2011-03-31     842
# 2011-04-30     749
# 2011-05-31     925
# 2011-06-30     854
# 2011-07-31     824
# 2011-08-31     793
# 2011-09-30    1096
# 2011-10-31    1199
# 2011-11-30    1462
# 2011-12-31     539
# Freq: M, Name: CustomerID, dtype: int64

# %% [markdown]
# Since we have only data up to 20011-12-09, i.e. not the whole Dec, let's remove the Decemeber data in 2011 for our cohort analysis

# %%
df_uk = df_uk[(df_uk.InvoiceDate.dt.date < dt.date(2011, 12, 1))]

# %% [markdown]
# Now, let's explore each customer's first spending by month and allocate them to that cohort.

# %%
cohort = df_uk.groupby('CustomerID')['InvoiceDate']\
                            .min().dt.to_period('m')
cohort = cohort.to_frame()

# Rename a column
cohort.columns = ['Cohort']
cohort.head()
# Out:
#              Cohort
# CustomerID
# 12747       2010-12
# 12748       2010-12
# 12749       2011-05
# 12820       2011-01
# 12821       2011-05

# %%
df_uk_cohort = df_uk.set_index('CustomerID').join(cohort)

# %% [markdown]
# After joining the new column, we can check what cohort a customer belongs to.
#
# In order to calculate the retention rate of each cohort over the 12-month period, we need to find out the months in which each customer placed their orders. So, let us create an additional column SalesPeriod by converting InvoiceDate to month period:

# %%
# create a new column by converting InvoiceDate to Month period
df_uk_cohort['SalesPeriod'] = df_uk_cohort['InvoiceDate']\
                                        .dt.to_period('m')

# %%
# Let's check customer 12747
df_uk_cohort.loc[12747]
# Out:
#             InvoiceNo StockCode                         Description  Quantity  \
# CustomerID
# 12747          537215    85124C       GREEN JUICY FRUIT PHOTO FRAME        12
# 12747          537215    85124B        BLUE JUICY FRUIT PHOTO FRAME         6
# 12747          537215     84879       ASSORTED COLOUR BIRD ORNAMENT        16
# 12747          537215     85062  PEARL CRYSTAL PUMPKIN T-LIGHT HLDR        24
# 12747          537215     85064        CREAM SWEETHEART LETTER RACK         6
# ...               ...       ...                                 ...       ...
# 12747          577104     85062  PEARL CRYSTAL PUMPKIN T-LIGHT HLDR        12
# 12747          577104     21745     GAOLERS KEYS DECORATIVE GARDEN          4
# 12747          577104     23522              WALL ART DOG AND BALL          6
# 12747          577104     23521              WALL ART CAT AND BIRD          6
# 12747          577104     23581              JUMBO BAG PAISLEY PARK        10
#
#                    InvoiceDate  UnitPrice         Country  Amount   Cohort  \
# CustomerID
# 12747      2010-12-05 15:38:00       2.55  United Kingdom   30.60  2010-12
# 12747      2010-12-05 15:38:00       2.55  United Kingdom   15.30  2010-12
# 12747      2010-12-05 15:38:00       1.69  United Kingdom   27.04  2010-12
# 12747      2010-12-05 15:38:00       1.65  United Kingdom   39.60  2010-12
# 12747      2010-12-05 15:38:00       5.45  United Kingdom   32.70  2010-12
# ...                        ...        ...             ...     ...      ...
# 12747      2011-11-17 17:13:00       1.65  United Kingdom   19.80  2010-12
# 12747      2011-11-17 17:13:00       3.75  United Kingdom   15.00  2010-12
# 12747      2011-11-17 17:13:00       2.89  United Kingdom   17.34  2010-12
# 12747      2011-11-17 17:13:00       2.89  United Kingdom   17.34  2010-12
# 12747      2011-11-17 17:13:00       2.08  United Kingdom   20.80  2010-12
#
#            SalesPeriod
# CustomerID
# 12747          2010-12
# 12747          2010-12
# 12747          2010-12
# 12747          2010-12
# 12747          2010-12
# ...                ...
# 12747          2011-11
# 12747          2011-11
# 12747          2011-11
# 12747          2011-11
# 12747          2011-11
#
# [90 rows x 10 columns]

# %%
# We can check the number of retained customers from each cohort over the 12-month period:
df_uk_cohort.reset_index(inplace=True)
df_uk_cohort.groupby(['Cohort', 'SalesPeriod'])\
                           .CustomerID.nunique()
# Out:
# Cohort   SalesPeriod
# 2010-12  2010-12        777
#          2011-01        274
#          2011-02        244
#          2011-03        280
#          2011-04        274
#                        ...
# 2011-09  2011-10         61
#          2011-11         84
# 2011-10  2011-10        322
#          2011-11         78
# 2011-11  2011-11        295
# Name: CustomerID, Length: 78, dtype: int64

# %% [markdown]
# To have a better illustration of the results, we can create a heatmap. But before that we need to create a pivot table for plotting purpose:

# %%
# create a copy of the rentention data and reset index
retention = df_uk_cohort.groupby(['Cohort', 'SalesPeriod']).\
                        CustomerID.nunique().reset_index()
# create a pivot table
retention = retention.pivot(index='SalesPeriod',columns='Cohort',
                            values='CustomerID')
retention
# Out:
# Cohort       2010-12  2011-01  2011-02  2011-03  2011-04  2011-05  2011-06  \
# SalesPeriod
# 2010-12        777.0      NaN      NaN      NaN      NaN      NaN      NaN
# 2011-01        274.0    343.0      NaN      NaN      NaN      NaN      NaN
# 2011-02        244.0     68.0    326.0      NaN      NaN      NaN      NaN
# 2011-03        280.0     89.0     58.0    415.0      NaN      NaN      NaN
# 2011-04        274.0     79.0     63.0     63.0    270.0      NaN      NaN
# 2011-05        306.0    112.0     92.0    108.0     56.0    251.0      NaN
# 2011-06        275.0     94.0     93.0     82.0     54.0     48.0    208.0
# 2011-07        255.0     85.0     83.0     95.0     56.0     43.0     36.0
# 2011-08        269.0     86.0     79.0     68.0     53.0     42.0     29.0
# 2011-09        301.0    104.0     85.0    108.0     61.0     54.0     49.0
# 2011-10        279.0    112.0     87.0     97.0     61.0     57.0     51.0
# 2011-11        383.0    123.0    101.0    113.0     70.0     68.0     66.0
#
# Cohort       2011-07  2011-08  2011-09  2011-10  2011-11
# SalesPeriod
# 2010-12          NaN      NaN      NaN      NaN      NaN
# 2011-01          NaN      NaN      NaN      NaN      NaN
# 2011-02          NaN      NaN      NaN      NaN      NaN
# 2011-03          NaN      NaN      NaN      NaN      NaN
# 2011-04          NaN      NaN      NaN      NaN      NaN
# 2011-05          NaN      NaN      NaN      NaN      NaN
# 2011-06          NaN      NaN      NaN      NaN      NaN
# 2011-07        171.0      NaN      NaN      NaN      NaN
# 2011-08         28.0    139.0      NaN      NaN      NaN
# 2011-09         35.0     29.0    270.0      NaN      NaN
# 2011-10         41.0     31.0     61.0    322.0      NaN
# 2011-11         48.0     33.0     84.0     78.0    295.0

# %%
# define a function to calculate the retention rate
def reten_rate (df):
    for x in range(len(df)):
        df.iloc[:,x] = df.iloc[:,x].divide(df.iloc[x,x])
    return df

# %%
reten_rate(retention)
# Out:
# Cohort        2010-12   2011-01   2011-02   2011-03   2011-04   2011-05  \
# SalesPeriod
# 2010-12      1.000000       NaN       NaN       NaN       NaN       NaN
# 2011-01      0.352638  1.000000       NaN       NaN       NaN       NaN
# 2011-02      0.314028  0.198251  1.000000       NaN       NaN       NaN
# 2011-03      0.360360  0.259475  0.177914  1.000000       NaN       NaN
# 2011-04      0.352638  0.230321  0.193252  0.151807  1.000000       NaN
# 2011-05      0.393822  0.326531  0.282209  0.260241  0.207407  1.000000
# 2011-06      0.353925  0.274052  0.285276  0.197590  0.200000  0.191235
# 2011-07      0.328185  0.247813  0.254601  0.228916  0.207407  0.171315
# 2011-08      0.346203  0.250729  0.242331  0.163855  0.196296  0.167331
# 2011-09      0.387387  0.303207  0.260736  0.260241  0.225926  0.215139
# 2011-10      0.359073  0.326531  0.266871  0.233735  0.225926  0.227092
# 2011-11      0.492921  0.358601  0.309816  0.272289  0.259259  0.270916
#
# Cohort        2011-06   2011-07   2011-08   2011-09   2011-10  2011-11
# SalesPeriod
# 2010-12           NaN       NaN       NaN       NaN       NaN      NaN
# 2011-01           NaN       NaN       NaN       NaN       NaN      NaN
# 2011-02           NaN       NaN       NaN       NaN       NaN      NaN
# 2011-03           NaN       NaN       NaN       NaN       NaN      NaN
# 2011-04           NaN       NaN       NaN       NaN       NaN      NaN
# 2011-05           NaN       NaN       NaN       NaN       NaN      NaN
# 2011-06      1.000000       NaN       NaN       NaN       NaN      NaN
# 2011-07      0.173077  1.000000       NaN       NaN       NaN      NaN
# 2011-08      0.139423  0.163743  1.000000       NaN       NaN      NaN
# 2011-09      0.235577  0.204678  0.208633  1.000000       NaN      NaN
# 2011-10      0.245192  0.239766  0.223022  0.225926  1.000000      NaN
# 2011-11      0.317308  0.280702  0.237410  0.311111  0.242236      1.0

# %%
# visualize the result using heatmap
fig, ax = plt.subplots(figsize=(16,6))
ax = sns.heatmap(retention, annot=True, cmap='Purples', fmt='.0%')
ax.set_ylabel('Sales Period', fontsize = 14)
ax.set_xlabel('Cohort Group', fontsize = 14)
ax.set_title('Retention Rates Across Cohorts', fontsize = 16);
